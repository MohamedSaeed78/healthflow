# %%
# !pip install -q imageio
# !pip install -q opencv-python
# !pip install -q git+https://github.com/tensorflow/docs
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for tensorflow-docs (setup.py) ... done

# %%
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow_docs.vis import embed
import numpy as np
import cv2

# Import matplotlib libraries
from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.patches as patches

import matplotlib.pyplot as plt

from PIL import Image
import tensorflow as tf
import tensorflow.keras.backend as K
from google.colab.patches import cv2_imshow
from tensorflow.python.ops.numpy_ops import np_config
import pandas as pd
# Some modules to display an animation using imageio.
import imageio
from IPython.display import HTML, display

# %% [markdown]
# # loading the data

# %%
trueData=np.load('push-upT.npy')
falseData=np.load('push-upF.npy')

# %% [markdown]
# # Data Analysis

# %%
trueData=np.squeeze(trueData)
falseData=np.squeeze(falseData)

# %%
trueLabes=np.ones((trueData.shape[0],1))
falseLabels=np.zeros((falseData.shape[0],1))

# %%
def mean_std_x_y(data):
  # calculate the mean x and y values for each keypoint separately
  mean_x = np.mean(data[:,:,0], axis=0)
  mean_y = np.mean(data[:,:,1], axis=0)

  # define the connections between keypoints
  connections = [(0,1), (0,2), (1,3), (2,4), (0,5), (0,6), (5,7), (7,9), (6,8), (8,10), (5,6), (5,11), (6,12), (11,12), (11,13), (13,15), (12,14), (14,16)]
  # specify the size of the figure
  plt.figure(figsize=(8, 6))
  # plot the mean x and y values for each keypoint and connect them
  for i, (x, y) in enumerate(zip(mean_x, mean_y)):
      plt.scatter(x, y)
      for a, b in connections:
          plt.plot([mean_x[a], mean_x[b]], [mean_y[a], mean_y[b]], color='gray', linestyle='-', linewidth=1)

  plt.xlabel('Mean X')
  plt.ylabel('Mean Y')
  plt.legend()
#########################################################################################

  # calculate the standard deviation of the x and y values for each keypoint separately
  std_x = np.std(data[:,:,0], axis=0)
  std_y = np.std(data[:,:,1], axis=0)

  # create a bar chart of the standard deviation of the x and y values for each keypoint
  x = np.arange(17)
  width = 0.35
  fig, ax = plt.subplots()
  rects1 = ax.bar(x - width/2, std_x, width, label='X')
  rects2 = ax.bar(x + width/2, std_y, width, label='Y')
  ax.set_xlabel('Keypoint')
  ax.set_ylabel('Standard deviation')
  ax.set_title('Standard deviation of X and Y values for each keypoint')
  ax.set_xticks(x)
  ax.legend()
  plt.show()

# %%
def heatmap_x_y(data):
  # create a heatmap of the distribution of keypoints
  fig, ax = plt.subplots()
  hist = ax.hist2d(data[:,:,0].flatten(), data[:,:,1].flatten(), bins=50)
  ax.set_xlabel('X')
  ax.set_ylabel('Y')
  ax.set_title('Heatmap of the distribution of keypoints')
  fig.colorbar(hist[3], ax=ax)
  plt.show()

# %%
def mean_std_confi(data):
  # calculate the mean confidence for each keypoint separately
  mean_conf = np.mean(data[:,:,2], axis=0)

  # create a bar chart of the mean confidence for each keypoint
  x = np.arange(17)
  width = 0.35
  fig, ax = plt.subplots()
  rects1 = ax.bar(x, mean_conf, width)
  ax.set_xlabel('Keypoint')
  ax.set_ylabel('Mean confidence')
  ax.set_title('Mean confidence for each keypoint')
  ax.set_xticks(x)
  plt.show()
############################################################################
  # calculate the standard deviation of the confidence for each keypoint separately
  std_conf = np.std(data[:,:,2], axis=0)

  # create a bar chart of the standard deviation of the confidence for each keypoint
  x = np.arange(17)
  width = 0.35
  fig, ax = plt.subplots()
  rects1 = ax.bar(x, std_conf, width)
  ax.set_xlabel('Keypoint')
  ax.set_ylabel('Standard deviation')
  ax.set_title('Standard deviation of confidence for each keypoint')
  ax.set_xticks(x)
  plt.show()

# %% [markdown]
# # True Data

# %%
mean_std_x_y(trueData)
# Out:
# <ipython-input-6-b9fbf47a67e0>:18: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
heatmap_x_y(trueData)

# %%
mean_std_confi(trueData)

# %% [markdown]
# # False Data

# %%
mean_std_x_y(falseData)
# Out:
# <ipython-input-6-b9fbf47a67e0>:18: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
heatmap_x_y(falseData)

# %%
mean_std_confi(falseData)

# %% [markdown]
# # Generating The Dataset

# %%
Data=np.concatenate((trueData, falseData))
labels=np.concatenate((trueLabes, falseLabels))
Data=Data.reshape((Data.shape[0], -1))

# %%
dataSet = pd.DataFrame(Data)
dataSet['Label'] = labels
print(dataSet)
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.747617  0.027183  0.174259  0.748045  0.014124  0.246906  0.743853
# 1     0.751827  0.026958  0.163232  0.763970  0.014111  0.258530  0.747115
# 2     0.750515  0.041016  0.155581  0.762055  0.016690  0.233119  0.744263
# 3     0.765065  0.030398  0.177163  0.764575  0.016468  0.238537  0.747152
# 4     0.748946  0.028378  0.167683  0.760741  0.014341  0.241328  0.731145
# ...        ...       ...       ...       ...       ...       ...       ...
# 2907  0.160294  0.560444  0.037392  0.011149  0.578996  0.156516  0.013168
# 2908  0.168252  0.559679  0.037502  0.016397  0.557096  0.130574  0.126451
# 2909  0.198551  0.552769  0.027209  0.014954  0.555936  0.128349  0.154506
# 2910  0.198691  0.538245  0.028109  0.016653  0.554594  0.128319  0.155009
# 2911  0.177285  0.542216  0.031445  0.014156  0.557679  0.124333  0.150364
#
#              7         8         9  ...        42        43        44  \
# 0     0.015989  0.224464  0.672153  ...  0.658880  0.529152  0.467292
# 1     0.015295  0.222779  0.673468  ...  0.658454  0.531312  0.507938
# 2     0.026528  0.212977  0.669985  ...  0.651184  0.541405  0.464274
# 3     0.025871  0.219520  0.671843  ...  0.652769  0.537750  0.544565
# 4     0.016376  0.211067  0.667917  ...  0.654663  0.541012  0.441608
# ...        ...       ...       ...  ...       ...       ...       ...
# 2907  0.545843  0.176114  0.016400  ...  0.635164  0.566409  0.085196
# 2908  0.543486  0.027042  0.062494  ...  0.617016  0.555354  0.102477
# 2909  0.535155  0.032011  0.062231  ...  0.600989  0.555036  0.101224
# 2910  0.533732  0.034182  0.050592  ...  0.616215  0.553635  0.094304
# 2911  0.536748  0.029219  0.060378  ...  0.600440  0.554116  0.105582
#
#             45        46        47        48        49        50  Label
# 0     0.714735  0.710669  0.658660  0.705563  0.687660  0.780241    1.0
# 1     0.716025  0.709508  0.642865  0.705503  0.688065  0.782760    1.0
# 2     0.721696  0.712696  0.634205  0.708522  0.695326  0.727396    1.0
# 2911  0.684945  0.739923  0.487609  0.701584  0.735670  0.335074    1.0
#
# [2912 rows x 52 columns]

# %% [markdown]
# # spliting the dataset

# %%
from sklearn.model_selection import train_test_split
train_val_data, test_data = train_test_split(dataSet, test_size=0.2, random_state=42)  # 80% train/validation, 20% test
train_data, val_data = train_test_split(train_val_data, test_size=0.25, random_state=42)  # 60% train, 20% validation
print(test_data)
# Out:
#              0         1         2         3         4         5         6  \
# 178   0.395931  0.743575  0.208498  0.380095  0.734617  0.364594  0.374728
# 678   0.828840  0.823190  0.181337  0.825407  0.827166  0.230147  0.827485
# 2872  0.014196  0.550120  0.195344  0.007382  0.560185  0.214010  0.006359
# 2845  0.674919  0.752345  0.282573  0.661650  0.757010  0.303822  0.661758
# 1898  0.019483  0.675702  0.064278  0.011855  0.683247  0.060509  0.006486
# ...        ...       ...       ...       ...       ...       ...       ...
# 1221  0.212150  0.466603  0.019523  0.029169  0.514792  0.091229  0.154354
# 542   0.390288  0.770325  0.145757  0.367083  0.768901  0.090200  0.367134
# 2313  0.591094  0.363416  0.096866  0.721322  0.328284  0.018546  0.724107
# 1644  0.274823  0.720565  0.056468  0.262229  0.717422  0.061950  0.246115
# 1591  0.054580  0.709371  0.040275  0.038320  0.743144  0.034663  0.005599
#
#              7         8         9  ...        42        43        44  \
# 178   0.740084  0.270722  0.383687  ...  0.813809  0.748240  0.137699
# 678   0.814982  0.261608  0.789429  ...  0.776276  0.441601  0.553957
# 2872  0.616220  0.186514  0.011047  ...  0.631407  0.627282  0.079426
# 2845  0.755179  0.314832  0.664749  ...  0.965852  0.773105  0.165358
# 1898  0.677417  0.077188  0.004839  ...  0.452386  0.712557  0.106252
# ...        ...       ...       ...  ...       ...       ...       ...
# 1221  0.450730  0.039244  0.163741  ...  0.633967  0.487437  0.113334
# 542   0.768852  0.119488  0.369536  ...  0.755114  0.735957  0.041954
# 2313  0.137897  0.153622  0.742960  ...  0.687642  0.537279  0.294671
# 1644  0.731062  0.047226  0.272657  ...  0.562576  0.748282  0.412252
# 1591  0.710759  0.102177  0.002945  ...  0.517060  0.741957  0.234358
#
#             45        46        47        48        49        50  Label
# 178   0.863507  0.702904  0.091407  0.884638  0.724712  0.075749    1.0
# 678   0.706706  0.293530  0.598765  0.731511  0.280952  0.591917    1.0
# 2872  0.692520  0.580979  0.143396  0.791056  0.568993  0.053865    0.0
# 2845  0.997125  0.785733  0.049846  0.993601  0.756213  0.066336    0.0
# 1898  0.687286  0.736579  0.452215  0.594185  0.719464  0.118508    1.0
# ...        ...       ...       ...       ...       ...       ...    ...
# 1221  0.795937  0.576722  0.032995  0.775321  0.490304  0.042106    0.0
# 542   0.862679  0.734683  0.011332  0.875165  0.720921  0.021822    1.0
# 2313  0.731314  0.722944  0.803460  0.710045  0.702267  0.493765    1.0
# 1644  0.694585  0.739612  0.554244  0.706819  0.738621  0.366552    1.0
# 1591  0.688866  0.739376  0.480147  0.700769  0.742059  0.511316    1.0
#
# [583 rows x 52 columns]

# %%
xtrain=train_data.iloc[:, :51].values
ytrain=train_data['Label'].values
xtest=test_data.iloc[:, :51].values
ytest=test_data['Label'].values
xval=val_data.iloc[:, :51].values
yval=val_data['Label'].values

# %%
xtrain=xtrain.reshape((xtrain.shape[0], 17,3))
xtest=xtest.reshape((xtest.shape[0], 17,3))
xval=xval.reshape((xval.shape[0], 17,3))

# %% [markdown]
# # Form Correctness Model

# %%
import tensorflow as tf

# Define the input shape
input_shape = (17,3)

# Create a sequential model
model = tf.keras.models.Sequential()

# Add a flatten layer to flatten the input into a vector
model.add(tf.keras.layers.Flatten(input_shape=input_shape))

# Add a dense layer with 64 nodes, using ReLU activation
model.add(tf.keras.layers.Dense(64, activation='relu'))

# Add a dropout layer to prevent overfitting
model.add(tf.keras.layers.Dropout(0.2))

# Add another dense layer with 32 nodes, using ReLU activation
model.add(tf.keras.layers.Dense(32, activation='relu'))

# Add the output layer with 1 node, using sigmoid activation
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# Compile the model with binary crossentropy loss and Adam optimizer
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model on your data
history = model.fit(xtrain, ytrain, epochs=50, batch_size=32, validation_data=(xval, yval))
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6125 - loss: 0.6505 - val_accuracy: 0.8508 - val_loss: 0.4982
# Epoch 2/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7907 - loss: 0.4833 - val_accuracy: 0.8902 - val_loss: 0.3370
# Epoch 3/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8397 - loss: 0.3755 - val_accuracy: 0.8954 - val_loss: 0.2621
# Epoch 4/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8839 - loss: 0.2824 - val_accuracy: 0.9228 - val_loss: 0.2346
# Epoch 5/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9043 - loss: 0.2381 - val_accuracy: 0.9451 - val_loss: 0.1694
# Epoch 6/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9345 - loss: 0.1897 - val_accuracy: 0.9400 - val_loss: 0.1542
# Epoch 7/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9581 - loss: 0.1462 - val_accuracy: 0.9640 - val_loss: 0.1190
# Epoch 8/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9594 - loss: 0.1221 - val_accuracy: 0.9657 - val_loss: 0.1041
# Epoch 9/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9756 - loss: 0.0921 - val_accuracy: 0.9760 - val_loss: 0.0891
# Epoch 10/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9666 - loss: 0.1070 - val_accuracy: 0.9743 - val_loss: 0.0824
# Epoch 11/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9675 - loss: 0.0972 - val_accuracy: 0.9743 - val_loss: 0.0812
# Epoch 12/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9651 - loss: 0.0934 - val_accuracy: 0.9743 - val_loss: 0.0747
# Epoch 13/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9773 - loss: 0.0775 - val_accuracy: 0.9777 - val_loss: 0.0731
# Epoch 14/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9805 - loss: 0.0598 - val_accuracy: 0.9691 - val_loss: 0.0804
# Epoch 15/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9813 - loss: 0.0568 - val_accuracy: 0.9777 - val_loss: 0.0674
# Epoch 16/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9881 - loss: 0.0499 - val_accuracy: 0.9760 - val_loss: 0.0674
# Epoch 17/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9837 - loss: 0.0523 - val_accuracy: 0.9794 - val_loss: 0.0634
# Epoch 18/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9888 - loss: 0.0483 - val_accuracy: 0.9760 - val_loss: 0.0614
# Epoch 19/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9815 - loss: 0.0522 - val_accuracy: 0.9777 - val_loss: 0.0619
# Epoch 20/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9893 - loss: 0.0471 - val_accuracy: 0.9794 - val_loss: 0.0589
# Epoch 21/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9788 - loss: 0.0609 - val_accuracy: 0.9794 - val_loss: 0.0578
# Epoch 22/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9806 - loss: 0.0553 - val_accuracy: 0.9777 - val_loss: 0.0579
# Epoch 23/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9780 - loss: 0.0631 - val_accuracy: 0.9777 - val_loss: 0.0581
# Epoch 24/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9896 - loss: 0.0390 - val_accuracy: 0.9828 - val_loss: 0.0585
# Epoch 25/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0437 - val_accuracy: 0.9726 - val_loss: 0.0718
# Epoch 26/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9885 - loss: 0.0427 - val_accuracy: 0.9811 - val_loss: 0.0599
# Epoch 27/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9888 - loss: 0.0396 - val_accuracy: 0.9846 - val_loss: 0.0533
# Epoch 28/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9839 - loss: 0.0482 - val_accuracy: 0.9777 - val_loss: 0.0536
# Epoch 29/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9888 - loss: 0.0403 - val_accuracy: 0.9811 - val_loss: 0.0556
# Epoch 30/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9903 - loss: 0.0325 - val_accuracy: 0.9794 - val_loss: 0.0504
# Epoch 31/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9927 - loss: 0.0239 - val_accuracy: 0.9811 - val_loss: 0.0675
# Epoch 32/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9890 - loss: 0.0354 - val_accuracy: 0.9828 - val_loss: 0.0518
# Epoch 33/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9952 - loss: 0.0239 - val_accuracy: 0.9846 - val_loss: 0.0571
# Epoch 34/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9921 - loss: 0.0259 - val_accuracy: 0.9811 - val_loss: 0.0486
# Epoch 35/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9863 - loss: 0.0390 - val_accuracy: 0.9846 - val_loss: 0.0498
# Epoch 36/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9918 - loss: 0.0300 - val_accuracy: 0.9863 - val_loss: 0.0500
# Epoch 37/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9853 - loss: 0.0382 - val_accuracy: 0.9863 - val_loss: 0.0494
# Epoch 38/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9944 - loss: 0.0233 - val_accuracy: 0.9811 - val_loss: 0.0528
# Epoch 39/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9943 - loss: 0.0224 - val_accuracy: 0.9863 - val_loss: 0.0474
# Epoch 40/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9939 - loss: 0.0249 - val_accuracy: 0.9811 - val_loss: 0.0602
# Epoch 41/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9926 - loss: 0.0246 - val_accuracy: 0.9863 - val_loss: 0.0429
# Epoch 42/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9903 - loss: 0.0341 - val_accuracy: 0.9863 - val_loss: 0.0442
# Epoch 43/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9962 - loss: 0.0221 - val_accuracy: 0.9863 - val_loss: 0.0479
# Epoch 44/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9897 - loss: 0.0288 - val_accuracy: 0.9828 - val_loss: 0.0493
# Epoch 45/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9899 - loss: 0.0345 - val_accuracy: 0.9794 - val_loss: 0.0514
# Epoch 46/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9904 - loss: 0.0276 - val_accuracy: 0.9846 - val_loss: 0.0463
# Epoch 47/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9948 - loss: 0.0182 - val_accuracy: 0.9811 - val_loss: 0.0469
# Epoch 48/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9957 - loss: 0.0162 - val_accuracy: 0.9846 - val_loss: 0.0483
# Epoch 49/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9967 - loss: 0.0189 - val_accuracy: 0.9811 - val_loss: 0.0456
# Epoch 50/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9954 - loss: 0.0195 - val_accuracy: 0.9708 - val_loss: 0.0829

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 51)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         3,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,325 (63.77 KB)
#  Trainable params: 5,441 (21.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 10,884 (42.52 KB)

# %%
test_loss, test_acc = model.evaluate(xtest, ytest)

print('Test accuracy:', test_acc)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9820 - loss: 0.0486
# Test accuracy: 0.9845626354217529

# %% [markdown]
# # Saving The Model

# %%
from google.colab import files

# %%
model.save('Pushup.h5')

# Convert the saved TensorFlow model to a TensorFlow Lite model

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the converted TensorFlow Lite model to a file

with open('Pushup.tflite', 'wb') as f:
    f.write(tflite_model)
files.download('Pushup.tflite')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved artifact at '/tmp/tmp1th7sgos'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 17, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   134218537394704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134218537395856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134218537396240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134218537396432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134218537396624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134218537398160: TensorSpec(shape=(), dtype=tf.resource, name=None)
